# %% [markdown]
# ### Battle of Neighbourhood - Business Proposal

# %% [markdown]
# ### Introduction

# %% [markdown]
# Off late there has been steady growth in immigration to Canada.
# Before one migrates to Canada, they need to study and understand how and where they need to live.
# One also needs to consider economic situation so that one can afford better life for themselves as well as their family.
#
# The aim of this study is to identifying rather exploring better facilities around their neighborhood of Toronto, Canada.
# It will help people making smart and efficient decision on selecting great neighborhood out of numbers of other neighborhoods in North York,Toranto.
#
# For someone who is migrating with their family, they need to consider various factors such as affordability of rent, community, School, Super market, medical shops, grocery shops, mall, theatre, hospital, like minded people,  etc.
#
# This study is an attempt to analyze features for a people migrating to North York to search a best neighborhood as a comparative analysis between neighborhoods. The features include housing price and better school according to ratings, infrastructure/connectivity, crime rates of that particular area, weather conditions, good management for emergency, water resources etc.
#
# This will help people to get awareness of the area and neighborhood before considering moving to a new city, state, country or place which they may be considering that would be close to their job.

# %% [markdown]
# ### Description of how the problem will be addressed and solved

# %% [markdown]
# The study here is being done on
#
#     1. Sorting the housing prices (in ascedning / descending order)
#     2. Sort schools in terms of fees, ratings and reviews and also location of the housing that is being considered.
#
# As the above two are important for a new immigrant, who is migrating with their family.

# %% [markdown]
# # Approach

# %% [markdown]
# The location that is being considered here is North York, Toronoto, for the purpose of study.
#
# This project would use
#
#     1. Foursquare API - as data gathering resource. Using Foursquare API neighbourhood places would be mined.
#     2. Clustering - Explore the neighbourhood, segmnent & group them, using k-means clustering algorithm.

# %% [markdown]
# ## Libraries being used

# %% [markdown]
# The below mentioned libraries would be used for the study.
#     1. Pandas
#     2. Matplotlib
#     3. Folium
#     4. Geocoder
#     5. Scikit Learn
#     6. JSON
#     7. XML
#     8. BeautifulSoup

# %% [markdown]
# ## Data Description

# %% [markdown]
# Source of data: https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M

# %% [markdown]
# ## Use of Foursquare API

# %% [markdown]
# Data would be needed for different neighbourhood of specific borough. In order to extract that data Foursquare API location information would be used.
#
# After finding the neighbourhood, connection would be established to gather information about venues around the neighbourhood.
#
# The chosen radius for neighbourhood is 100 meters.
#
# Using Foursquare API the below data would be fetched.
#
# 1. Neighbourhood
# 2. Latitude
# 3. Longitutde
# 4. Venues
# 5. Name of Venue
# 6. Latitude and longitude of venue
# 7. Category of the venue

# %% [markdown]
# ## Map of North York, Toronto, Canada

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Method

# %% [markdown]
# # Clustering Approach:
# To compare the similarities of two cities, it was decided to explore neighborhoods, segment them, and group them into clusters to find similar neighborhoods in a big city like New York and Toronto. To be able to do that, we need to cluster data which is a form of unsupervised machine learning: k-means clustering algorithm.

# %% [markdown]
# ## Using K-Means Clustering Approach

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Bar Graph of Housing in North York, Toronto, Canada

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## School ratings in North York, Toronto, Canada

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Conclusion

# %% [markdown]
#     1. In this activity, using k-means cluster algorithm was used to separate the neighborhood into 10(Ten) different clusters and for 180 different lattitude and logitude from dataset, which have very-similar neighborhoods around them.
#
#     2. Using the charts above results presented to a particular neighborhood based on average house prices and school rating have been made.

# %% [markdown]
# ## Thank you!
